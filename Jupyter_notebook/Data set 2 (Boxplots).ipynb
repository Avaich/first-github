# %%
import seaborn as sns
import pandas as pd
import numpy as np

#importing data file
chilla2 = pd.read_csv("Chilla_data2_for_plots.csv")
chilla2.head()
# Out:
#         Timestamp  Gender  Location    Age Qualification_completed  \
# 0  1/4/2022 18:02    Male  Pakistan  36-40                 Masters
# 1  1/4/2022 18:02    Male  Pakistan  26-30               Bachelors
# 2  1/4/2022 18:03    Male  Pakistan  31-35                 Masters
# 3  1/4/2022 18:03  Female  Pakistan  31-35                 Masters
# 4  1/4/2022 18:03  Female  Pakistan  26-30                 Masters
#
#      field_of_study        Purpose_for_chilla  \
# 0  Natural Sciences     to boost my skill set
# 1             CS/IT     to boost my skill set
# 2       Enginnering  Switch my field of study
# 3             CS/IT     to boost my skill set
# 4       Enginnering     to boost my skill set
#
#    Research/Working experience (Float/Int) years  Age (years)-Float/Int  \
# 0                                            5.0                  38.00
# 1                                            1.0                  25.00
# ...

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#Canvas (Baloon board)
sns.set_theme(style="ticks", color_codes=True)
#Load dataset
sns.boxenplot(x="Qualification_completed", y="Age (years)-Float/Int", hue="Gender", data=chilla2)
# Out:
# <AxesSubplot:xlabel='Qualification_completed', ylabel='Age (years)-Float/Int'>

# %% [markdown]
# ## Renaming x axis, y axis and title of the graph

# %%
sns.boxplot(x="Qualification_completed", y="Age (years)-Float/Int", hue="Gender", data=chilla2)
plt.xlabel("Qualification Completed"),
plt.ylabel("Age(years)"),
plt.title("Box plot of Qualification vs Age in Male/Female")
# Out:
# Text(0.5, 1.0, 'Box plot of Qualification vs Age in Male/Female')

# %% [markdown]
# ## Changing size and making text bold

# %%
sns.boxplot(x="Qualification_completed", y="Age (years)-Float/Int", hue="Gender", data=chilla2)
plt.xlabel("Qualification Completed", size=14),
plt.ylabel("Age(years)", size=12),
plt.title("Box plot of Qualification vs Age in Male/Female", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Box plot of Qualification vs Age in Male/Female')

# %% [markdown]
# ## Changing color of each hue color

# %%
sns.boxplot(x="Qualification_completed", y="Age (years)-Float/Int", hue="Gender", data=chilla2, palette={"Male": "0.4", "Female": "0.8"})
plt.xlabel("Qualification Completed", size=14),
plt.ylabel("Age(years)", size=12),
plt.title("Box plot of Qualification vs Age in Male/Female", size=16, weight="bold")
# Out:
# Text(0.5, 1.0, 'Box plot of Qualification vs Age in Male/Female')
